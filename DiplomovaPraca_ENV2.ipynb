# %%
pip install -U pip setuptools wheel
# Out:
# ...
#   Using cached setuptools-67.6.0-py3-none-any.whl (1.1 MB)
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.6.3
#     Uninstalling setuptools-65.6.3:
#       Successfully uninstalled setuptools-65.6.3
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U spacy
# Out:
# ...
#      ---------------------------------------- 0.0/12.2 MB ? eta -:--:--
#       --------------------------------------- 0.2/12.2 MB 5.0 MB/s eta 0:00:03
#      - -------------------------------------- 0.4/12.2 MB 4.9 MB/s eta 0:00:03
#      - -------------------------------------- 0.5/12.2 MB 4.7 MB/s eta 0:00:03
#      -- ------------------------------------- 0.6/12.2 MB 3.5 MB/s eta 0:00:04
#      -- ------------------------------------- 0.8/12.2 MB 3.5 MB/s eta 0:00:04
#      --- ------------------------------------ 0.9/12.2 MB 3.4 MB/s eta 0:00:04
#      --- ------------------------------------ 1.1/12.2 MB 3.4 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.2/12.2 MB 3.4 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.2/12.2 MB 3.4 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.4/12.2 MB 3.2 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.6/12.2 MB 3.1 MB/s eta 0:00:04
# ...

# %%
import spacy

# %%
pip install git+https://github.com/boudinfl/pke.git
# Out:
# ...
#   Cloning https://github.com/boudinfl/pke.git to c:\users\uzivatel\appdata\local\temp\pip-req-build-abq6nkbb
#   Resolved https://github.com/boudinfl/pke.git to commit 8f1d05dcc52041c9920ba0f9d5231fe6086d12c4
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      --- ------------------------------------ 0.1/1.5 MB 4.3 MB/s eta 0:00:01
#      ------ --------------------------------- 0.2/1.5 MB 3.7 MB/s eta 0:00:01
#      --------- ------------------------------ 0.4/1.5 MB 2.9 MB/s eta 0:00:01
#      --------------- ------------------------ 0.6/1.5 MB 3.3 MB/s eta 0:00:01
#      ----------------- ---------------------- 0.7/1.5 MB 3.3 MB/s eta 0:00:01
#      ---------------------- ----------------- 0.8/1.5 MB 3.3 MB/s eta 0:00:01
#      --------------------------- ------------ 1.0/1.5 MB 3.4 MB/s eta 0:00:01
# ...

# %%
import pke

# %%
text1 = open('FinalText1.txt','r').read()
text2 = open('FinalText2.txt','r').read()
text3 = open('FinalText3.txt','r').read()
text4 = open('FinalText4.txt','r').read()
text5 = open('FinalText5.txt','r').read()
text6 = open('FinalText6.txt','r').read()
text7 = open('FinalText7.txt','r').read()
text8 = open('FinalText8.txt','r').read()
text9 = open('FinalText9.txt','r').read()
text10 = open('FinalText10.txt','r').read()

# %%
print(text10)
# Out:
# Thank you to those who checked in during my absence here. Delighted to be missed and you will I hope be happy to know that I have been busy working on new projects. This past week Susanna and I were on a few adventures in Los Angeles and beyond. Our first shoot was in Santa Barbara so on the recommendation of designer Madeline Stuart who we were visiting there we took the doubledecker Amtrak Surfliner up the coast. Even leaving from LA was a treat as we departed from the majestic Union Station.Built in the 1939 for 11 million the station is an architectural gem in what has been coined Mission Moderne style  a melding of Spanish Colonial Mission Revival and Art Deco. Its a shame train travel has somewhat lost its allure in the states because leaving from a station such as this sets the tone for any upcoming trip and certainly beats the stress of the airport. Thank goodness it has been designated a Los Angeles HistoricCultural Monument and placed on the National Register of Historic Pl
# ...

# %%
extractor = pke.supervised.Kea()

# %%
stoplist = pke.lang.stopwords.get('en')

# %%
extractor.load_document(text1,
                        language='en',
                        stoplist=stoplist,
                        normalization=None)

# %%
extractor.candidate_selection()

# %%
pos = {'NOUN'}

# %%
extractor.candidate_weighting()
# Out:
# WARNING:root:LoadFile._df_counts is hard coded to C:\Users\uzivatel\anaconda3\envs\env2\lib\site-packages\pke\models\df-semeval2010.tsv.gz
# C:\Users\uzivatel\anaconda3\envs\env2\lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator MultinomialNB from version 0.20.0 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
keyphrasesTxt1 = extractor.get_n_best(n=18)

# %%
keyphrasesTxt1
# Out:
# [('romeo', 0.04493185263928967),
#  ('juliet', 0.018601365772471897),
#  ('capulet', 0.013375163909035022),
#  ('paris', 0.009691857792707748),
#  ('tybalt', 0.007050505340566887),
#  ('prince', 0.006789105827183582),
#  ('mercutio', 0.0066352643093560305),
#  ('verona', 0.006348177050993007),
#  ('benvolio', 0.006304898546329435),
#  ('ball', 0.006205538654811248),
#  ('death', 0.006129816875747524),
#  ('montague', 0.0057107739732431256),
#  ('declares', 0.005577504291315256),
#  ('count paris', 0.005488416319327842),
#  ('talks', 0.005476645341950645),
#  ('capulet ball', 0.005331609444284711),
#  ('friar', 0.005253442522984762),
#  ('italy', 0.005237298152293001)]

# %%
extractor.load_document(text2,
                        language='en',
                        stoplist=stoplist,
                        normalization=None)

# %%
extractor.candidate_selection()

# %%
extractor.candidate_weighting()
# Out:
# WARNING:root:LoadFile._df_counts is hard coded to C:\Users\uzivatel\anaconda3\envs\env2\lib\site-packages\pke\models\df-semeval2010.tsv.gz
# C:\Users\uzivatel\anaconda3\envs\env2\lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator MultinomialNB from version 0.20.0 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
keyphrasesTxt2 = extractor.get_n_best(n=10)

# %%
keyphrasesTxt2
# Out:
# [('battery', 0.049931682008941256),
#  ('batteries', 0.01844618541936229),
#  ('hybrids', 0.010617499147339081),
#  ('battery life', 0.008599839120075423),
#  ('costs', 0.008476586388397178),
#  ('capacity', 0.008252379358218634),
#  ('miles', 0.007915248727472554),
#  ('phevs', 0.007401832573576634),
#  ('release', 0.007390806958690253),
#  ('consumption', 0.006986875530273486)]

# %%
import pke
extractor = pke.supervised.Kea()
stoplist = pke.lang.stopwords.get('en')
extractor.load_document(text3,
                        language='en',
                        stoplist=stoplist,
                        normalization=None)
extractor.candidate_selection()
extractor.candidate_weighting()
keyphrasesTxt3 = extractor.get_n_best(n=14)
# Out:
# WARNING:root:LoadFile._df_counts is hard coded to C:\Users\uzivatel\anaconda3\envs\env2\lib\site-packages\pke\models\df-semeval2010.tsv.gz
# C:\Users\uzivatel\anaconda3\envs\env2\lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator MultinomialNB from version 0.20.0 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [('autistic', 0.050002973210251205),
#  ('autistic children', 0.013556968794910345),
#  ('people', 0.011062615972646907),
#  ('communication', 0.010918672000172977),
#  ('expressions', 0.009870640144000867),
#  ('eye contact', 0.009425028382586912),
#  ('facial', 0.008597785820373634),
#  ('facial expressions', 0.008597785820373634),
#  ('language', 0.008465872219659746),
#  ('autistic people', 0.008383481050037347),
# ...

# %%
extractor.load_document(text4,
                        language='en',
                        stoplist=stoplist,
                        normalization=None)
extractor.candidate_selection()
extractor.candidate_weighting()
keyphrasesTxt4 = extractor.get_n_best(n=17)
keyphrasesTxt4
# Out:
# WARNING:root:LoadFile._df_counts is hard coded to C:\Users\uzivatel\anaconda3\envs\env2\lib\site-packages\pke\models\df-semeval2010.tsv.gz
# C:\Users\uzivatel\anaconda3\envs\env2\lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator MultinomialNB from version 0.20.0 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [('robot', 0.04977285067870149),
#  ('techniques', 0.017105041658326364),
#  ('mechanical', 0.011899514419808892),
#  ('mechanical structure', 0.011899514419808892),
#  ('structure', 0.011885251685307605),
#  ('tasks', 0.011757644783850257),
#  ('robotic', 0.011492681639138224),
#  ('information', 0.01141024163026656),
#  ('position', 0.011260616993876689),
#  ('achieve', 0.010745594616400202),
#  ('systems', 0.010657714710086565),
# ...

# %%
extractor.load_document(text5,
                        language='en',
                        stoplist=stoplist,
                        normalization=None)
extractor.candidate_selection()
extractor.candidate_weighting()
keyphrasesTxt5 = extractor.get_n_best(n=14)
keyphrasesTxt5
# Out:
# WARNING:root:LoadFile._df_counts is hard coded to C:\Users\uzivatel\anaconda3\envs\env2\lib\site-packages\pke\models\df-semeval2010.tsv.gz
# C:\Users\uzivatel\anaconda3\envs\env2\lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator MultinomialNB from version 0.20.0 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [('reactions', 0.04922344727729116),
#  ('cells', 0.014346325228109936),
#  ('chemical', 0.012208118229820703),
#  ('atp', 0.011961462254394404),
#  ('coenzyme', 0.010440044224054692),
#  ('groups', 0.009217580503653067),
#  ('coenzymes', 0.008492480529728735),
#  ('chemical reactions', 0.00760250877048915),
#  ('types', 0.0074263742549147355),
#  ('atoms', 0.0072373014629213755),
#  ('molecules', 0.007152946517355212),
# ...

# %%
extractor.load_document(text6,
                        language='en',
                        stoplist=stoplist,
                        normalization=None)
extractor.candidate_selection()
extractor.candidate_weighting()
keyphrasesTxt6 = extractor.get_n_best(n=14)
keyphrasesTxt6
# Out:
# WARNING:root:LoadFile._df_counts is hard coded to C:\Users\uzivatel\anaconda3\envs\env2\lib\site-packages\pke\models\df-semeval2010.tsv.gz
# C:\Users\uzivatel\anaconda3\envs\env2\lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator MultinomialNB from version 0.20.0 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [('queen', 0.04521048483013387),
#  ('snow white', 0.026034965015279046),
#  ('snow', 0.016953693850123425),
#  ('magic', 0.015127927359162689),
#  ('mirror', 0.011284462798807104),
#  ('white', 0.010993212194125971),
#  ('fairest', 0.010783152354554425),
#  ('princess', 0.00981942004844102),
#  ('magical', 0.008295271704409692),
#  ('land', 0.006868718931241331),
#  ('tells', 0.006737698398205735),
#  ('dwarfs', 0.006704904260941905),
# ...

# %%
extractor.load_document(text7,
                        language='en',
                        stoplist=stoplist,
                        normalization=None)
extractor.candidate_selection()
extractor.candidate_weighting()
keyphrasesTxt7 = extractor.get_n_best(n=8)
keyphrasesTxt7
# Out:
# WARNING:root:LoadFile._df_counts is hard coded to C:\Users\uzivatel\anaconda3\envs\env2\lib\site-packages\pke\models\df-semeval2010.tsv.gz
# C:\Users\uzivatel\anaconda3\envs\env2\lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator MultinomialNB from version 0.20.0 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [('developers', 0.04928078675443723),
#  ('web3', 0.023115709874883834),
#  ('services', 0.019753795049631425),
#  ('chainlink', 0.01448893340350174),
#  ('smart contracts', 0.014156466680958579),
#  ('contracts', 0.014140042180094844),
#  ('el moujahid', 0.013608447109587581),
#  ('moujahid', 0.013592649660976576)]

# %%
extractor.load_document(text8,
                        language='en',
                        stoplist=stoplist,
                        normalization=None)
extractor.candidate_selection()
extractor.candidate_weighting()
keyphrasesTxt8 = extractor.get_n_best(n=7)
keyphrasesTxt8
# Out:
# WARNING:root:LoadFile._df_counts is hard coded to C:\Users\uzivatel\anaconda3\envs\env2\lib\site-packages\pke\models\df-semeval2010.tsv.gz
# C:\Users\uzivatel\anaconda3\envs\env2\lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator MultinomialNB from version 0.20.0 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [('bank', 0.04991189599406736),
#  ('hatch', 0.0436583613176463),
#  ('hatch bank', 0.0436583613176463),
#  ('vulnerability', 0.022487892160651585),
#  ('security', 0.021822767807320457),
#  ('goanywhere', 0.021537859606725555),
#  ('zeroday', 0.016436742917782094)]

# %%
extractor.load_document(text9,
                        language='en',
                        stoplist=stoplist,
                        normalization=None)
extractor.candidate_selection()
extractor.candidate_weighting()
keyphrasesTxt9 = extractor.get_n_best(n=9)
keyphrasesTxt9
# Out:
# WARNING:root:LoadFile._df_counts is hard coded to C:\Users\uzivatel\anaconda3\envs\env2\lib\site-packages\pke\models\df-semeval2010.tsv.gz
# C:\Users\uzivatel\anaconda3\envs\env2\lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator MultinomialNB from version 0.20.0 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [('san patrignano', 0.048553118800227814),
#  ('patrignano', 0.04850208309371422),
#  ('community', 0.02968168597155713),
#  ('san', 0.025536817865771843),
#  ('recovery', 0.013212011193777346),
#  ('susanna', 0.011845849629351491),
#  ('craftsmanship', 0.010383961555617832),
#  ('conversation', 0.008111668937528918),
#  ('fine craftsmanship', 0.007988105958745224)]

# %%
extractor.load_document(text10,
                        language='en',
                        stoplist=stoplist,
                        normalization=None)
extractor.candidate_selection()
extractor.candidate_weighting()
keyphrasesTxt10 = extractor.get_n_best(n=8)
keyphrasesTxt10
# Out:
# WARNING:root:LoadFile._df_counts is hard coded to C:\Users\uzivatel\anaconda3\envs\env2\lib\site-packages\pke\models\df-semeval2010.tsv.gz
# C:\Users\uzivatel\anaconda3\envs\env2\lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator MultinomialNB from version 0.20.0 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [('santa', 0.04593378620903493),
#  ('santa barbara', 0.04593378620903493),
#  ('barbara', 0.04586528836788578),
#  ('historic', 0.021169905974502166),
#  ('delighted', 0.015366351747097622),
#  ('projects', 0.014877201924280105),
#  ('susanna', 0.014763016838563906),
#  ('los', 0.01455965509081573)]

# %%
from pke import compute_document_frequency
from string import punctuation

# %%
stoplist=list(punctuation)

# %%
corpus = [text1,text2,text3,text4,text5,text6,text7,text8,text9,text10]

# %% [markdown]
# TextRank

# %%
pos = {'NOUN'}

# %%
extractorTR = pke.unsupervised.TextRank()
extractorTR.load_document(text1,
                        language='en',
                        normalization=None)

extractorTR.candidate_weighting(window=2,
                              pos=pos,
                              top_percent=0.33)

TRtxt1 = extractorTR.get_n_best(n=18)

# %%
extractorTR.load_document(text1,
                        language='en',
                        normalization=None)

# %%
extractorTR.candidate_weighting(window=2,
                              pos=pos,
                              top_percent=0.33)
# Out:
# WARNING:root:Candidates are generated using 0.33-top

# %%
TRtxt1 = extractorTR.get_n_best(n=18)

# %%
TRtxt1
# Out:
# [('feuding families', 0.09188863926888854),
#  ('deathlike coma', 0.09188693926888855),
#  ('romeo confronts', 0.09188562926888855),
#  ('plague o', 0.09188547926888856),
#  ('street brawl', 0.09188178926888856),
#  ('cousin romeo', 0.053149763349851706),
#  ('confronts', 0.04594732463444427),
#  ('families', 0.04594362463444428),
#  ('romeo', 0.045941954634444275),
#  ('cousin', 0.007209598715407429),
#  ('nieces', 0.007209238715407428),
#  ('girl', 0.007209158715407429),
#  ('infatuation', 0.007209128715407428),
#  ('depression', 0.007209038715407429),
#  ('son', 0.007208978715407428),
#  ('courtship', 0.007208848715407429),
#  ('ball', 0.007208688715407428),
#  ('years', 0.007208598715407429)]

# %%
extractorTR.load_document(text2,
                        language='en',
                        normalization=None)
extractorTR.candidate_weighting(window=2,
                              pos=pos,
                              top_percent=0.33)
TRtxt2 = extractorTR.get_n_best(n=10)
# Out:
# WARNING:root:Candidates are generated using 0.33-top
# [('influences battery life', 0.10633127493870054),
#  ('battery life', 0.08711583141476013),
#  ('battery', 0.06789817789081973),
#  ('power storage', 0.044275225479335954),
#  ('leveling purposes', 0.034104425853735514),
#  ('recycling program', 0.034103845853735514),
#  ('plug-in hybrids', 0.034103565853735515),
#  ('payback period', 0.03410350585373552),
#  ('electricity prices', 0.03410333585373552),
#  ('iron phosphates', 0.03410313585373552)]

# %%
extractorTR.load_document(text3,
                        language='en',
                        normalization=None)
extractorTR.candidate_weighting(window=2,
                              pos=pos,
                              top_percent=0.33)
TRtxt3 = extractorTR.get_n_best(n=14)
TRtxt3
# Out:
# WARNING:root:Candidates are generated using 0.33-top
# [('language skills', 0.11618059545489115),
#  ('language impairment', 0.09726256748671502),
#  ('language expression', 0.09725983748671503),
#  ('body language', 0.09725922748671502),
#  ('language', 0.07578070705195873),
#  ('autism spectrum', 0.07511201399466158),
#  ('autism activism', 0.07511089399466157),
#  ('share experiences', 0.0675505259476413),
#  ('word combinations', 0.0675503159476413),
#  ('anxiety disorders', 0.0675471459476413),
#  ('eye contact', 0.0675468159476413),
#  ('communication skills', 0.06242646948669616),
#  ('share', 0.03377793297382065),
#  ('anxiety', 0.03377398297382065)]

# %%
extractorTR.load_document(text4,
                        language='en',
                        normalization=None)
extractorTR.candidate_weighting(window=2,
                              pos=pos,
                              top_percent=0.33)
TRtxt4 = extractorTR.get_n_best(n=17)
TRtxt4
# Out:
# WARNING:root:Candidates are generated using 0.33-top
# [('control techniques', 0.0633239732384698),
#  ('robot control', 0.06288510648936041),
#  ('force control', 0.0549045453115106),
#  ('mapping techniques', 0.05008104950939064),
#  ('robot controllers', 0.04046613375830018),
#  ('control', 0.0388482134417863),
#  ('sensor', 0.03737663369457631),
#  ('reference architecture', 0.035787842580357394),
#  ('feedback signals', 0.03565780071025729),
#  ('end effector', 0.035657040710257284),
#  ('architecture controllers', 0.0338034589840865),
#  ('development studies', 0.032109153739448615),
#  ('research scientists', 0.03210735373944862),
#  ('system developers', 0.032107293739448615),
#  ('communication networks', 0.032106263739448616),
#  ('programming tools', 0.03210614373944862),
#  ('operator interfaces', 0.03210611373944862)]

# %%
extractorTR.load_document(text5,
                        language='en',
                        normalization=None)
extractorTR.candidate_weighting(window=2,
                              pos=pos,
                              top_percent=0.33)
TRtxt5 = extractorTR.get_n_best(n=14)
TRtxt5
# Out:
# WARNING:root:Candidates are generated using 0.33-top
# [('chemical energy', 0.13475684272912816),
#  ('chemical reactions', 0.13475559272912815),
#  ('chemical groups', 0.10873611950998996),
#  ('hydrogen atoms', 0.10411027118566016),
#  ('hydrogen acceptor', 0.10410985118566016),
#  ('nad+/nadh form', 0.09368598227879738),
#  ('adenosine triphosphate', 0.09368357227879738),
#  ('metabolic intermediates', 0.09368289227879738),
#  ('phosphorylation reactions', 0.08615796866320105),
#  ('energy currency', 0.08615704866320106),
#  ('reactions', 0.055514702212444755),
#  ('form', 0.04684433113939869),
#  ('intermediates', 0.04684179113939869),
#  ('atoms', 0.03641697223253588)]

# %%
extractorTR.load_document(text6,
                        language='en',
                        normalization=None)
extractorTR.candidate_weighting(window=2,
                              pos=pos,
                              top_percent=0.33)
TRtxt6 = extractorTR.get_n_best(n=14)
TRtxt6
# Out:
# WARNING:root:Candidates are generated using 0.33-top
# [('animal friends', 0.07029648573920873),
#  ('moat boat', 0.07029576573920873),
#  ('poison apple', 0.07029556573920873),
#  ('potion calls', 0.07029480573920872),
#  ('pet raven', 0.07029430573920874),
#  ('love song', 0.07029209573920873),
#  ('herself body', 0.07028968573920873),
#  ('fairy tales', 0.07028925573920873),
#  ('apple', 0.035152472869604365),
#  ('herself', 0.03515184286960436),
#  ('potion', 0.035150032869604365),
#  ('spirits', 0.005471805426079143),
#  ('soul', 0.005471765426079143),
#  ('witchcraft', 0.005471695426079143)]

# %%
extractorTR.load_document(text7,
                        language='en',
                        normalization=None)
extractorTR.candidate_weighting(window=2,
                              pos=pos,
                              top_percent=0.33)
TRtxt7 = extractorTR.get_n_best(n=8)
TRtxt7
# Out:
# WARNING:root:Candidates are generated using 0.33-top
# [('web3 services platform', 0.08262052159924975),
#  ('part web', 0.05832337234689797),
#  ('web services', 0.051073899757701754),
#  ('access web', 0.04348531329348153),
#  ('serverless platform', 0.041229748623127026),
#  ('test nets', 0.03879067640766419),
#  ('beta mode', 0.038790616407664194),
#  ('business logic', 0.03879030640766419)]

# %%
extractorTR.load_document(text8,
                        language='en',
                        normalization=None)
extractorTR.candidate_weighting(window=2,
                              pos=pos,
                              top_percent=0.33)
TRtxt8 = extractorTR.get_n_best(n=7)
TRtxt8
# Out:
# WARNING:root:Candidates are generated using 0.33-top
# [('file transfer software', 0.09361784347958757),
#  ('credit monitoring', 0.06954501738927357),
#  ('file transfer', 0.06631244328392123),
#  ('cybersecurity training', 0.04608642354965087),
#  ('law enforcement', 0.046086073549650865),
#  ('attorney general', 0.04608443354965087),
#  ('healthcare providers', 0.04608403354965087)]

# %%
extractorTR.load_document(text9,
                        language='en',
                        normalization=None)
extractorTR.candidate_weighting(window=2,
                              pos=pos,
                              top_percent=0.33)
TRtxt9 = extractorTR.get_n_best(n=9)
TRtxt9
# Out:
# WARNING:root:Candidates are generated using 0.33-top
# [('design lab division', 0.09433837114493922),
#  ('design community', 0.08082919435340423),
#  ('design workshops', 0.07140618668762763),
#  ('design client', 0.07140473668762763),
#  ('design contacts', 0.07140203668762764),
#  ('design friends', 0.07140161668762764),
#  ('drug rehabilitation center', 0.05987047109808713),
#  ('family style cafeteria', 0.059869791098087134),
#  ('design', 0.059674728226967816)]

# %%
extractorTR.load_document(text10,
                        language='en',
                        normalization=None)
extractorTR.candidate_weighting(window=2,
                              pos=pos,
                              top_percent=0.33)
TRtxt10 = extractorTR.get_n_best(n=8)
TRtxt10
# Out:
# WARNING:root:Candidates are generated using 0.33-top
# [('shame train travel', 0.12177711265544784),
#  ('video visits', 0.08118903510363187),
#  ('backyard garden', 0.08118807510363188),
#  ('afternoon light', 0.08118796510363188),
#  ('weekend retreat', 0.08118776510363188),
#  ('rebuilding process', 0.08118673510363188),
#  ('style structure', 0.08118622510363188),
#  ('style', 0.04059310755181594)]

# %% [markdown]
# TF-IDF

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import re
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer

# %% [markdown]
# stopwords=get_stop_words("StopWords.txt") #Source = https://www.ranks.nl/stopwords

# %%
stop_words = set(stopwords.words('english'))

# %%
stop_words = list(stop_words)

# %%
import re
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
stop_words = set(stopwords.words('english'))
stop_words = list(stop_words)

def pre_process(text):
    text=text.lower()
    text=re.sub("(\\d|\\W)+"," ",text)
    text = text.split()
    text = [word for word in text if word not in stop_words]
    
    lmtzr = WordNetLemmatizer()
    text = [lmtzr.lemmatize(word) for word in text]
    
    return ' '.join(text)

# %%
[x.lower() for x in corpus]
# Out:
# ['the play, set in verona, italy, begins with a street brawl between montague and capulet servants who, like the masters they serve, are sworn enemies. prince escalus of verona intervenes and declares that further breach of the peace will be punishable by death. later, count paris talks to capulet about marrying his daughter juliet, but capulet asks paris to wait another two years and invites him to attend a planned capulet ball. lady capulet and juliet\'s nurse try to persuade juliet to accept paris\'s courtship.meanwhile, benvolio talks with his cousin romeo, montague\'s son, about romeo\'s recent depression. benvolio discovers that it stems from unrequited infatuation for a girl named rosaline, one of capulet\'s nieces. persuaded by benvolio and mercutio, romeo attends the ball at the capulet house in hopes of meeting rosaline. however, romeo instead meets and falls in love with juliet. juliet\'s cousin, tybalt, is enraged at romeo for sneaking into the ball but is only stopped fr
# ...

# %%
list(map(lambda x:pre_process(x), corpus)) #https://stackoverflow.com/questions/1801668/convert-a-list-with-strings-all-to-lowercase-or-uppercase
# Out:
# ['play set verona italy begin street brawl montague capulet servant like master serve sworn enemy prince escalus verona intervenes declares breach peace punishable death later count paris talk capulet marrying daughter juliet capulet asks paris wait another two year invite attend planned capulet ball lady capulet juliet nurse try persuade juliet accept paris courtship meanwhile benvolio talk cousin romeo montague son romeo recent depression benvolio discovers stem unrequited infatuation girl named rosaline one capulet niece persuaded benvolio mercutio romeo attends ball capulet house hope meeting rosaline however romeo instead meet fall love juliet juliet cousin tybalt enraged romeo sneaking ball stopped killing romeo juliet father wish shed blood house ball famously known balcony scene romeo sneak capulet orchard overhears juliet window vowing love spite family hatred montagues romeo make known agree married help friar laurence hope reconcile two family child union secretly married 
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words=stop_words, smooth_idf=True, use_idf=True)
vectorizer.fit_transform(corpus)

# %%
vectorizer.fit_transform(corpus)
# Out:
# <10x1909 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2292 stored elements in Compressed Sparse Row format>

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_df=0.85,stop_words=stop_words)
word_count_vector=cv.fit_transform(corpus)

# %%
word_count_vector=cv.fit_transform(corpus)

# %%
list(cv.vocabulary_.keys())[:10]
# Out:
# ['play',
#  'set',
#  'verona',
#  'italy',
#  'begins',
#  'street',
#  'brawl',
#  'montague',
#  'capulet',
#  'servants']

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)
tfidf_transformer.fit(word_count_vector)

# %%
tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)

# %%
tfidf_transformer.fit(word_count_vector)
# Out:
# TfidfTransformer()

# %%
tf_idf_vector=tfidf_transformer.transform(cv.transform([corpus[0]]))

# %%
def sort(matrix):
    tuples = zip(matrix.col, matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

# %%
def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    sorted_items = sorted_items[:topn]
    score_vals = []
    feature_vals = []

    for idx, score in sorted_items:
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])
    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    
    return results

# %%
sorted_items=sort(tf_idf_vector.tocoo())

# %%
feature_names = cv.get_feature_names_out()

# %%
keywords1=extract_topn_from_vector(feature_names,sorted_items,18)

# %%
for k in keywords1:
    print(k,keywords1[k])   #https://kavita-ganesan.com/python-keyword-extraction/
# Out:
# romeo 0.639
# juliet 0.384
# capulet 0.281
# paris 0.205
# tybalt 0.153
# mercutio 0.128
# ball 0.128
# friar 0.102
# families 0.102
# benvolio 0.102
# prince 0.087
# death 0.087
# dead 0.087
# verona 0.077
# laurence 0.077
# two 0.061
# talks 0.051
# secretly 0.051

# %%
tf_idf_vector=tfidf_transformer.transform(cv.transform([corpus[1]]))

# %%
sorted_items=sort_coo(tf_idf_vector.tocoo())

# %%
keywords2=extract_topn_from_vector(feature_names,sorted_items,10)
keywords2
# Out:
# {'battery': 0.467,
#  'batteries': 0.311,
#  'plug': 0.195,
#  'hybrids': 0.195,
#  'phevs': 0.156,
#  'capacity': 0.156,
#  'less': 0.132,
#  'vehicles': 0.117,
#  'release': 0.117,
#  'miles': 0.117}

# %%
tf_idf_vector=tfidf_transformer.transform(cv.transform([corpus[2]]))
sorted_items=sort_coo(tf_idf_vector.tocoo())
feature_names = cv.get_feature_names_out()
keywords3=extract_topn_from_vector(feature_names,sorted_items,14)
# Out:
# {'autistic': 0.547,
#  'may': 0.277,
#  'children': 0.219,
#  'people': 0.193,
#  'language': 0.193,
#  'expressions': 0.193,
#  'communication': 0.164,
#  'facial': 0.161,
#  'contact': 0.161,
#  'eye': 0.137,
#  'words': 0.129,
#  'nonverbal': 0.129,
#  'others': 0.109,
#  'less': 0.109}

# %%
tf_idf_vector=tfidf_transformer.transform(cv.transform([corpus[3]]))
sorted_items=sort_coo(tf_idf_vector.tocoo())
keywords4=extract_topn_from_vector(feature_names,sorted_items,17)
keywords4
# Out:
# {'robot': 0.46,
#  'control': 0.395,
#  'sensor': 0.197,
#  'techniques': 0.164,
#  'open': 0.132,
#  'controllers': 0.132,
#  'architecture': 0.132,
#  'used': 0.117,
#  'may': 0.109,
#  'tasks': 0.099,
#  'robotic': 0.099,
#  'reference': 0.099,
#  'real': 0.099,
#  'mechanical': 0.099,
#  'interconnected': 0.099,
#  'implementation': 0.099,
#  'time': 0.098}

# %%
tf_idf_vector=tfidf_transformer.transform(cv.transform([corpus[4]]))
sorted_items=sort_coo(tf_idf_vector.tocoo())
keywords5=extract_topn_from_vector(feature_names,sorted_items,14)
keywords5
# Out:
# {'reactions': 0.484,
#  'atp': 0.242,
#  'transfer': 0.206,
#  'cells': 0.206,
#  'coenzyme': 0.193,
#  'chemical': 0.193,
#  'nadh': 0.145,
#  'nad': 0.145,
#  'groups': 0.145,
#  'coenzymes': 0.145,
#  'small': 0.123,
#  'set': 0.123,
#  'vitamins': 0.097,
#  'vitamin': 0.097}

# %%
tf_idf_vector=tfidf_transformer.transform(cv.transform([corpus[5]]))
sorted_items=sort_coo(tf_idf_vector.tocoo())
keywords6=extract_topn_from_vector(feature_names,sorted_items,14)
keywords6
# Out:
# {'queen': 0.455,
#  'snow': 0.325,
#  'mirror': 0.292,
#  'white': 0.276,
#  'magic': 0.166,
#  'princess': 0.162,
#  'fairest': 0.162,
#  'dwarfs': 0.13,
#  'tells': 0.097,
#  'peddler': 0.097,
#  'old': 0.097,
#  'magical': 0.097,
#  'land': 0.097,
#  'humbert': 0.097}

# %%
tf_idf_vector=tfidf_transformer.transform(cv.transform([corpus[6]]))
sorted_items=sort_coo(tf_idf_vector.tocoo())
keywords7=extract_topn_from_vector(feature_names,sorted_items,8)
keywords7
# Out:
# {'developers': 0.363,
#  'web3': 0.285,
#  'smart': 0.257,
#  'web': 0.228,
#  'chainlink': 0.228,
#  'services': 0.218,
#  'platform': 0.2,
#  'moujahid': 0.2}

# %%
tf_idf_vector=tfidf_transformer.transform(cv.transform([corpus[7]]))
sorted_items=sort_coo(tf_idf_vector.tocoo())
keywords8=extract_topn_from_vector(feature_names,sorted_items,7)
keywords8
# Out:
# {'bank': 0.467,
#  'hatch': 0.297,
#  'vulnerability': 0.212,
#  'security': 0.212,
#  'goanywhere': 0.212,
#  'zeroday': 0.17,
#  'flaw': 0.17}

# %%
tf_idf_vector=tfidf_transformer.transform(cv.transform([corpus[8]]))
sorted_items=sort_coo(tf_idf_vector.tocoo())
keywords9=extract_topn_from_vector(feature_names,sorted_items,9)
keywords9
# Out:
# {'patrignano': 0.366,
#  'san': 0.311,
#  'community': 0.242,
#  'design': 0.242,
#  'recovery': 0.163,
#  'susanna': 0.138,
#  'craftsmanship': 0.122,
#  'year': 0.121,
#  'place': 0.104}

# %%
tf_idf_vector=tfidf_transformer.transform(cv.transform([corpus[9]]))
sorted_items=sort_coo(tf_idf_vector.tocoo())
keywords10=extract_topn_from_vector(feature_names,sorted_items,8)
keywords10
# Out:
# {'santa': 0.209,
#  'barbara': 0.209,
#  'station': 0.157,
#  'mission': 0.157,
#  'matthias': 0.157,
#  'historic': 0.157,
#  'took': 0.133,
#  'home': 0.133}

# %%
len(text1.split())
# Out:
# 647

# %%
len(text2.split())
# Out:
# 482

# %%
len(text3.split())
# Out:
# 559

# %%
len(text4.split())
# Out:
# 599

# %%
len(text5.split())
# Out:
# 327

# %%
len(text6.split())
# Out:
# 708

# %%
len(text7.split())
# Out:
# 655

# %%
len(text8.split())
# Out:
# 408

# %%
len(text9.split())
# Out:
# 715

# %%
len(text10.split())
# Out:
# 505
